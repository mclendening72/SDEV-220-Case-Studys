# %%
# Superclass: Vehicle
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type


# Subclass: Automobile
class Automobile(Vehicle):
    def __init__(self, vehicle_type, year, make, model, doors, roof):
        super().__init__(vehicle_type)   # get vehicle_type from class Vehicle
        self.year = year
        self.make = make
        self.model = model
        self.doors = doors
        self.roof = roof


# Main Program
def main():
    print("Please enter the information regarding your vehicle:\n")

    vehicle_type = input("Enter a vehicle type: Car, SUV, Truck: ")
    year = input("Enter the year: ")
    make = input("Enter the make: ")
    model = input("Enter the model: ")
    doors = input("Enter number of doors (2 or 4): ")
    roof = input("Enter roof type (solid or sun roof): ")

    # Create Automobile object
    auto = Automobile(vehicle_type, year, make, model, doors, roof)

    print(f"Type: {auto.vehicle_type}")
    print(f"Year: {auto.year}")
    print(f"Make: {auto.make}")
    print(f"Model: {auto.model}")
    print(f"Doors: {auto.doors}")
    print(f"Roof: {auto.roof}")


if __name__ == "__main__":
    main()
# Out:
# Please enter the information regarding your vehicle:
# Enter a vehicle type: Car, SUV, Truck:  SUV
# Enter the year:  2025
# Enter the make:  Jeep
# Enter the model:  Cherokee
# Enter number of doors (2 or 4):  4
# Enter roof type (solid or sun roof):  solid
# Type: SUV
# Year: 2025
# Make: Jeep
# Model: Cherokee
# Doors: 4
# Roof: solid
